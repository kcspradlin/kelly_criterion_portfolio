# %% [markdown]
# This notebook will demonstrate how to use Python and some of its modules to estimate parameters of a multi-variate Student's t distribution for a randomly-generated set of data.  It will use the maximum likelihood estimation (MLE) approach to find the parameters.
#
# Created on August 31 and September 3-5, 2022 by Kevin Spradlin, Jr.

# %% [markdown]
# First, import some Python modules.

# %%
import typing
import math
import numpy as np
import scipy.stats as stats
import scipy.optimize as optimize

# %% [markdown]
# Next, create a set of random multi-variate Student's t variates using the scipy.stats ***multivariate_t*** function.
#
# I used this site to learn about how it works: Taboga, Marco (2021). "Multivariate Student's t distribution", Lectures on probability theory and mathematical statistics. Kindle Direct Publishing. Online appendix. https://www.statlect.com/probability-distributions/multivariate-student-t-distribution.

# %%
def is_matrix_pos_semidef(test_matrix: np.array) -> typing.Dict:
    """
    This function will test the array test_matrix to see if it's positive 
     semi-definite, using this definition:

     "A positive semidefinite matrix is a Hermitian matrix all of whose eigenvalues are nonnegative."
     https://mathworld.wolfram.com/HermitianMatrix.html

     It will check if the matrix is square, Hermitian, and only has positive 
     eigenvalues.

     The function will return a dictionary.  One key is 'pass_test', which
      will be True if it's positive semi-definite and False if not.  The
      other key is 'message' will will state why the matrix failed the test,
      or will be blank it it passed the test.

    Created on June 8, 2022
    """

    pass_test: bool = False
    message: str = ''


    # check if the matrix is square
    matrix_dimensions: List = list(test_matrix.shape)

    if len(matrix_dimensions) != 2:
        message = 'Matrix needs to have 2 dimensions'
        return {'pass_test': pass_test, 'message': message}

    if matrix_dimensions[0] != matrix_dimensions[1]:
        message = 'Matrix needs to be square'
        return {'pass_test': pass_test, 'message': message}


    # check if the matrix is Hermitian
    complex_conjugate: np.array = np.matrix.getH(test_matrix)

    if not np.array_equal(test_matrix, complex_conjugate):
        message = "Matrix isn\'t Hermitian - equal to complex conjugate of itself"
        return {'pass_test': pass_test, 'message': message}


    # calculate the matrix's eigenvalues and check if any are negative
    for current_eigenvalue in np.linalg.eigvals(test_matrix):
        if current_eigenvalue < 0:
            message = f"Matrix has eigenvalue of {current_eigenvalue:6.4f}"
            break


    if message:
        return {'pass_test': pass_test, 'message': message}
    else:
        return {'pass_test': True, 'message': ''}

# %%
# let the user define the location vector, shape matrix, and degrees of freedom 
#  of the multi-variate Student's t distribution
mean_vector: np.ndarray = np.asarray([-0.105, 0.015], dtype=np.float32)
shape_matrix: np.ndarray = np.asarray([[0.65, -0.25], [-0.25, 0.20]], dtype=np.float32)
sample_df: int = 4

    
# check that the matrix is positive semi-definite
function_results: typing.Dict = is_matrix_pos_semidef(shape_matrix)

if not function_results['pass_test']:
    print(function_results['message'])    


# generate 10,000 random variates
random_sample: np.ndarray = stats.multivariate_t.rvs(loc=mean_vector, shape=shape_matrix, 
                                                     df=sample_df, size=10000)

# %% [markdown]
# Before we use the MLE approach, let's calculate the basic statistics of the sample of random multi-variate Student's t variates.
#
# They should show that the mean vector of the sample are close to the values you defined.  The standard deviations likely won't be close to the shape matrix you described - they should be close to (df / (df - 2)) * shape matrix.  The sample statistics shouldn't show that the skewnesses and especially the excess kurtosis (kurtoses ?) are close to zero, since this is a multi-variate Student's t distribution.

# %%
results = stats.describe(random_sample)
print(f"Sample means: {np.array2string(results[2], precision=4):s}")
print(f"Sample variances: {np.array2string(results[3], precision=4):s}")
print(f"Sample skewnesses: {np.array2string(results[4], precision=4):s}")
print(f"Sample excess kurtosis: {np.array2string(results[5], precision=4):s}")
# Out:
# Sample means: [-0.0957  0.0042]
# Sample variances: [1.3046 0.4172]
# Sample skewnesses: [ 0.0542 -0.6924]
# Sample excess kurtosis: [ 9.1708 13.0685]

# %% [markdown]
# ---
#
# Now, we'll use the MLE approach.
# First define a function that calculates the log-likelihood function.  Then find the parameters that maximize the log-likelihood function.

# %%
def decode_lh_parameters_students_t(parameters: np.ndarray, num_dimensions: int) -> typing.Dict:
    """
    This function will convert the elements of the parameters array into a
     location/mean vector, a shape matrix, and degrees of freedom.  It will
     return them as values in a dictionary.
    
    Created on August 30 and September 5, 2022
    """

    mean_vector: np.ndarray = parameters[0:num_dimensions]

    shape_matrix: np.ndarray = np.zeros((num_dimensions, num_dimensions), dtype=np.float32)

    addend: int = num_dimensions
    for current_column in range(num_dimensions):
        addend -= current_column
        
        for current_row1 in range(0, current_column):
            shape_matrix[current_row1, current_column] = shape_matrix[current_column, current_row1]
        
        for current_row2 in range(current_column, num_dimensions):
            shape_matrix[current_row2, current_column] = \
              parameters[current_row2 + current_column * num_dimensions + addend]
    
    df: float = parameters[-1]


    return {'mean_vector': mean_vector, 'shape_matrix': shape_matrix, 'degrees_freedom': df}

# %%
def trial_pos_semidef_matrix(test_matrix: np.array) -> typing.Dict:
    """
    This function will take a matrix return a new matrix, based on the
     eigendecomposition of the original matrix.  The original matrix's 
     eigenvalues and vectors will be calculated.  If any eigenvalues are
     non-positive, then they will be set to be slightly positive.  The
     new matrix will be calculated from the original matrix's eigenvectors,
     any of the original eigenvalues that are positive, and the adjusted, 
     now-slightly positive eigenvalues.
     
    The new matrix will be positive semi-definite.
    
    Got information about eigendecomposition from this site:
    https://mathworld.wolfram.com/EigenDecomposition.html
    
    Created on September 3, 2022
    """    
    
    message: str = ''
    
    
    # first, make sure the matrix is symmetric
    matrix_dimensions: List = list(test_matrix.shape)

    if len(matrix_dimensions) != 2:
        message = 'Matrix needs to have 2 dimensions'
        return {'any_errors': True, 'message': message}

    if matrix_dimensions[0] != matrix_dimensions[1]:
        message = 'Matrix needs to be square'
        return {'any_errors': True, 'message': message}

 
    if not np.array_equal(test_matrix, test_matrix.T):
        message = "Matrix isn\'t symmetric"
        return {'any_errors': True, 'message': message}
   

    # next, calculate the eigenvalues and eigenvectors of the matrix
    matrix_p: np.ndarray = np.zeros((matrix_dimensions[0], matrix_dimensions[0]), dtype=np.float32)
    matrix_d: np.ndarray = np.zeros((matrix_dimensions[0], matrix_dimensions[0]), dtype=np.float32)
    
    test_eigenvalues, test_eigenvectors = np.linalg.eig(test_matrix)

    
    for current_index, current_eigenvalue in enumerate(test_eigenvalues):
        matrix_p[:,current_index] = test_eigenvectors[:,current_index]
       
        if current_eigenvalue >= 0.0:
            matrix_d[current_index, current_index] = current_eigenvalue
        else:
            matrix_d[current_index, current_index] = np.random.rand() / 10.0

    
    adjusted_matrix: np.ndarray = np.matmul(matrix_p, matrix_d)
    adjusted_matrix = np.matmul(adjusted_matrix, np.linalg.inv(matrix_p))
 

    #print(f"Eigenvalues: {np.array2string(test_eigenvalues, precision=4):s}")
    #print(f"Eigenvectors: {np.array2string(test_eigenvectors, precision=4):s}")
    
    #print(f"Eigenvector matrix: {np.array2string(matrix_p, precision=4):s}")
    #print(f"Eigenvalue matrix: {np.array2string(matrix_d, precision=4):s}")
    #print(f"Test matrix: {np.array2string(test_matrix, precision=4):s}")
    #print(f"Adjusted matrix: {np.array2string(adjusted_matrix, precision=4):s}")
   
    
    return {'any_errors': False, 'message': '', 'adjusted_matrix': adjusted_matrix}

# %%
def log_likelihood_multivariate_students_t(parameters: np.ndarray, num_dimensions: int, variates: np.ndarray) -> float:
    """
    Returns the negative of the log-likelihood function.  The scipy.optimize module only
     has a 'minimize' function, so you need to use it to minimize the negative of the
     log-likelihood function, which will maximize the positive of the log-likelihood
     function.

    Expect parameters[0:dimension] to be the location vector, parameters[dimension:-1] are the
     elements of the lower triangle of the shape matrix, and parameters[-1] is the degrees of
     freedom.

    Created on August 31 and September 3, 2022
    """
    
    function_results: typing.Dict = decode_lh_parameters_students_t(parameters, num_dimensions)

    mean_vector: np.ndarray = function_results['mean_vector']

    shape_matrix: np.ndarray = function_results['shape_matrix']

    degrees_freedom: float = float(function_results['degrees_freedom'])

        
    # need to ensure that the shape matrix is positive definite or semi-definite
    # first, test it.  if it passes the test, then calculate the likelihood function
    # if it fails the test, calculate an adjusted shape matrix that passes the
    #  test and use it to calculate the likelihood function
    function_results: typing.Dict = is_matrix_pos_semidef(shape_matrix)

    if not function_results['pass_test']:
        other_function_results: typing.Dict = trial_pos_semidef_matrix(shape_matrix)
        
        if other_function_results['any_errors']:
            print(other_function_results['message'])
            return 0.0
        else:
            shape_matrix = other_function_results['adjusted_matrix']       
        
        
    temp_sum: float = -np.sum(stats.multivariate_t.logpdf(variates, 
                                                          loc=mean_vector, 
                                                          shape=shape_matrix, 
                                                          df=degrees_freedom))

    print(f"Log likelihood: {temp_sum:12.6f}")

    return temp_sum

# %% [markdown]
# In order to use the numpy ***minimize*** function, the parameters of the likelihood function need to be fed into the ***minimize*** function as a vector. <br><br>
# To do this, I set up a ***init_parameters*** one-dimensional NumPy array.  The first part of the array has the elements in the mean vector, most of the middle part of the array has the lower triangle of the shape matrix, and the last element is the degrees of freedom. <br><br>
# Suppose you want to estimate the parameters of multi-variate Student's t distribution with an n-dimensional mean vector and a n-by-n shape matrix.  The first n elements of the ***init_parameters*** array can store the values of the mean vector. <br><br>
# You need to ensure that the shape matrix that's used by the likelihood function is symmetric.  If you simply put every element of the matrix into the ***init_parameters*** array, then there's a good chance that the ***minimize*** function would set elements in the array so that the matrix would no longer be symmetric.  To ensure that this won't happen, I only save the elements of the lower triangle of the shape matrix in the ***init_parameters*** array.  Inside of the ***log_likelihood_multivariate_students_t*** function, I use the remaining elements in the array to set up a symmetric matrix.

# %% [markdown]
# Here's where I set up the ***init_parameters*** array.

# %%
num_dimensions: int = random_sample.shape[1]
num_elements: int = int(num_dimensions * (num_dimensions + 3) / 2) + 1

print(f"Number of dimensions: {num_dimensions:d}")
print(f"Number of parameters in optimization problem: {num_elements:d}")
    
init_parameters: np.ndarray = np.zeros(num_elements, dtype=np.float32)

# set the starting values for the mean vector equal to the sample means.
sample_stats = stats.describe(random_sample)

for current_element in range(num_dimensions):
#    init_parameters[current_element] = 1.0
    init_parameters[current_element] = sample_stats[2][current_element]

# now set the starting values for the covariance matrix.  set the diagonal
#  elements equal to the same variances.
current_element:int = num_dimensions
for step_size in range(num_dimensions, 0, -1):
    if current_element < num_elements:
        init_parameters[current_element] = sample_stats[3][num_dimensions - step_size]
        current_element += step_size

# finally set the starting value for degrees of freedom equal to the
#  number of dimensions
init_parameters[-1] = float(num_dimensions)


print(np.array2string(init_parameters, precision=4))
# Out:
# Number of dimensions: 2
# Number of parameters in optimization problem: 6
# [-0.0957  0.0042  1.3046  0.      0.4172  2.    ]

# %% [markdown]
# ---
#
# Finally, I run the ***minimize*** function to perform the MLE and obtain the estimated mean vector, shape matrix, and degrees of freedom.<br><br>
#
# You also need to add some boundary conditions for the optimization function.  It's easier to set them up at the same time you set up the ***init_parameters*** array.  The conditions are:
# * elements on the diagonal in the shape matrix need to be positive
# * the degrees of freedom needs to be positive.<br><br>
#
# You can see from the results that the values in the mean vector, shape matrix, and degrees of freedom are somewhat close to the values you originally entered.<br>

# %%
boundary_cond: typing.List = []

for index, value in enumerate(init_parameters):
    if index < num_dimensions:
        boundary_cond.append([None,None])
    else:
        if value == 1:
            boundary_cond.append([0,100000])
        else:
            boundary_cond.append([None,None])

boundary_cond[-1] = [1,100000]


opt_results = optimize.minimize(log_likelihood_multivariate_students_t, 
                                x0=init_parameters, 
                                args=(num_dimensions, random_sample, ), 
                                method='Nelder-Mead', bounds=boundary_cond,
                                options={'maxiter': num_elements * 1000,
                                         'maxfev': num_elements * 1000})

    
function_results: typing.Dict = decode_lh_parameters_students_t(opt_results['x'], num_dimensions)           

print(f"Estimated mean vector: {np.array2string(function_results['mean_vector'], precision=4):s}")
print(f"Estimated shape matrix: {np.array2string(function_results['shape_matrix'], precision=4):s}")
print(f"Estimated degrees of freedom: {function_results['degrees_freedom']:6.2f}")
print(opt_results['message'])

print(f"\nActual mean vector: {np.array2string(mean_vector, precision=4):s}")
print(f"Actual shape matrix: {np.array2string(shape_matrix, precision=4):s}")
print(f"Actual degrees of freedom: {sample_df:6.2f}")
# Out:
# Log likelihood: 24800.740558
# Log likelihood: 24800.664365
# Log likelihood: 24800.703513
# Log likelihood: 24892.564231
# Log likelihood: 24801.960365
# Log likelihood: 24896.833138
# Log likelihood: 24728.573341
# Log likelihood: 24711.528597
# Log likelihood: 24621.053116
# Log likelihood: 24623.684581
# Log likelihood: 24655.491286
# Log likelihood: 24609.165276
# Log likelihood: 24515.889771
# Log likelihood: 24515.946103
# Log likelihood: 24424.371394
# Log likelihood: 24247.033425
# Log likelihood: 24329.164118
# Log likelihood: 24295.022256
# Log likelihood: 24234.303036
# Log likelihood: 24081.984255
# Log likelihood: 24042.175034
# Log likelihood: 23785.052109
# Log likelihood: 23913.270673
# Log likelihood: 23762.086185
# Log likelihood: 23653.529476
# Log likelihood: 23672.823203
# Log likelihood: 23643.984022
# Log likelihood: 24446.383728
# Log likelihood: 23965.949961
# Log likelihood: 23557.196519
# Log likelihood: 24785.087367
# Log likelihood: 23861.623852
# Log likelihood: 23527.209439
# Log likelihood: 24243.341334
# Log likelihood: 24777.783998
# Log likelihood: 23643.350358
# Log likelihood: 24621.923859
# Log likelihood: 23609.845544
# Log likelihood: 23494.764753
# Log likelihood: 23639.944512
# Log likelihood: 23372.871572
# Log likelihood: 23265.864443
# Log likelihood: 23241.162105
# Log likelihood: 23071.027148
# Log likelihood: 23476.899092
# Log likelihood: 23773.089376
# Log likelihood: 23416.790438
# Log likelihood: 23194.851555
# Log likelihood: 23079.521616
# Log likelihood: 23047.069535
# Log likelihood: 23027.952699
# Log likelihood: 23480.789486
# Log likelihood: 23151.786893
# Log likelihood: 22856.620207
# Log likelihood: 22754.753415
# Log likelihood: 22777.923077
# Log likelihood: 22754.214414
# Log likelihood: 22883.825050
# Log likelihood: 23041.100536
# Log likelihood: 23033.719096
# Log likelihood: 23749.821878
# Log likelihood: 22885.839961
# Log likelihood: 22792.234838
# Log likelihood: 23091.882242
# Log likelihood: 22831.444659
# Log likelihood: 22592.487472
# Log likelihood: 22543.849201
# Log likelihood: 22646.011567
# Log likelihood: 22599.008559
# Log likelihood: 22794.557354
# Log likelihood: 22684.936292
# Log likelihood: 22563.277555
# Log likelihood: 22568.275081
# Log likelihood: 22705.483157
# Log likelihood: 22553.711882
# Log likelihood: 22775.803452
# Log likelihood: 22581.001990
# Log likelihood: 22765.806138
# Log likelihood: 22563.972521
# Log likelihood: 22661.127905
# Log likelihood: 22552.372368
# Log likelihood: 22609.238488
# Log likelihood: 22547.314988
# Log likelihood: 22583.812711
# Log likelihood: 22540.759509
# Log likelihood: 22571.393813
# Log likelihood: 22543.805602
# Log likelihood: 22570.139814
# Log likelihood: 22542.234501
# Log likelihood: 22563.223304
# Log likelihood: 22538.715555
# Log likelihood: 22567.390812
# Log likelihood: 22539.626174
# Log likelihood: 22552.223974
# Log likelihood: 22538.745700
# Log likelihood: 22551.873265
# Log likelihood: 22537.021256
# Log likelihood: 22544.338670
# Log likelihood: 22538.209839
# Log likelihood: 22543.029184
# Log likelihood: 22537.582286
# Log likelihood: 22541.972967
# Log likelihood: 22537.028734
# Log likelihood: 22542.373553
# Log likelihood: 22536.799638
# Log likelihood: 22539.283106
# Log likelihood: 22536.724536
# Log likelihood: 22541.030149
# Log likelihood: 22536.473358
# Log likelihood: 22537.084236
# Log likelihood: 22537.517183
# Log likelihood: 22536.289991
# Log likelihood: 22536.697231
# Log likelihood: 22536.072467
# Log likelihood: 22537.799129
# Log likelihood: 22540.169136
# Log likelihood: 22535.754743
# Log likelihood: 22536.497383
# Log likelihood: 22536.164498
# Log likelihood: 22536.793087
# Log likelihood: 22535.920204
# Log likelihood: 22535.667693
# Log likelihood: 22536.652398
# Log likelihood: 22535.149864
# Log likelihood: 22535.553840
# Log likelihood: 22537.445818
# Log likelihood: 22535.484129
# Log likelihood: 22536.727317
# Log likelihood: 22535.516715
# Log likelihood: 22536.043871
# Log likelihood: 22535.529297
# Log likelihood: 22535.014207
# Log likelihood: 22535.062924
# Log likelihood: 22535.244003
# Log likelihood: 22535.184453
# Log likelihood: 22534.642771
# Log likelihood: 22534.351045
# Log likelihood: 22534.435925
# Log likelihood: 22534.095594
# Log likelihood: 22533.803946
# Log likelihood: 22535.125717
# Log likelihood: 22534.015016
# Log likelihood: 22533.377435
# Log likelihood: 22532.823725
# Log likelihood: 22534.258172
# Log likelihood: 22532.998679
# Log likelihood: 22532.679784
# Log likelihood: 22532.370458
# Log likelihood: 22531.799311
# Log likelihood: 22530.913558
# Log likelihood: 22533.887695
# Log likelihood: 22531.487629
# Log likelihood: 22532.900870
# Log likelihood: 22530.329031
# Log likelihood: 22529.481963
# Log likelihood: 22530.342563
# Log likelihood: 22530.575444
# Log likelihood: 22529.377374
# Log likelihood: 22530.149980
# Log likelihood: 22529.332862
# Log likelihood: 22531.050683
# Log likelihood: 22528.708383
# Log likelihood: 22529.374155
# Log likelihood: 22528.589426
# Log likelihood: 22529.588661
# Log likelihood: 22530.030835
# Log likelihood: 22528.973290
# Log likelihood: 22529.693500
# Log likelihood: 22528.816396
# Log likelihood: 22529.499887
# Log likelihood: 22528.788021
# Log likelihood: 22530.027704
# Log likelihood: 22528.700528
# Log likelihood: 22527.728290
# Log likelihood: 22527.198107
# Log likelihood: 22529.296756
# Log likelihood: 22528.362419
# Log likelihood: 22527.909028
# Log likelihood: 22527.615527
# Log likelihood: 22527.748445
# Log likelihood: 22527.105918
# Log likelihood: 22527.062533
# Log likelihood: 22527.181794
# Log likelihood: 22525.911451
# Log likelihood: 22524.875052
# Log likelihood: 22526.836631
# Log likelihood: 22525.686229
# Log likelihood: 22525.021978
# Log likelihood: 22526.303323
# Log likelihood: 22524.958711
# Log likelihood: 22524.859747
# Log likelihood: 22525.727671
# Log likelihood: 22523.752173
# Log likelihood: 22523.368171
# Log likelihood: 22523.105580
# Log likelihood: 22522.758596
# Log likelihood: 22521.841480
# Log likelihood: 22520.517387
# Log likelihood: 22520.721415
# Log likelihood: 22520.251911
# Log likelihood: 22519.436222
# Log likelihood: 22517.422819
# Log likelihood: 22514.404791
# Log likelihood: 22514.415616
# Log likelihood: 22517.971386
# Log likelihood: 22512.170125
# Log likelihood: 22508.797290
# Log likelihood: 22510.396391
# Log likelihood: 22508.493301
# Log likelihood: 22506.671764
# Log likelihood: 22502.101142
# Log likelihood: 22495.207879
# Log likelihood: 22500.929050
# Log likelihood: 22500.227573
# Log likelihood: 22490.604967
# Log likelihood: 22481.385359
# Log likelihood: 22485.918082
# Log likelihood: 22485.223784
# Log likelihood: 22486.792201
# Log likelihood: 22480.387101
# Log likelihood: 22480.786940
# Log likelihood: 22467.449776
# Log likelihood: 22453.055323
# Log likelihood: 22467.751529
# Log likelihood: 22473.829630
# Log likelihood: 22464.242432
# Log likelihood: 22455.654382
# Log likelihood: 22452.796851
# Log likelihood: 22448.791592
# Log likelihood: 22441.977035
# Log likelihood: 22434.678601
# Log likelihood: 22439.747383
# Log likelihood: 22427.206543
# Log likelihood: 22417.297087
# Log likelihood: 22418.265720
# Log likelihood: 22420.645750
# Log likelihood: 22449.875698
# Log likelihood: 22432.246672
# Log likelihood: 22405.778021
# Log likelihood: 22396.173418
# Log likelihood: 22413.175561
# Log likelihood: 22410.580791
# Log likelihood: 22386.637073
# Log likelihood: 22371.555136
# Log likelihood: 22384.377547
# Log likelihood: 22396.905890
# Log likelihood: 22401.671047
# Log likelihood: 22381.832086
# Log likelihood: 22372.596473
# Log likelihood: 22377.541915
# Log likelihood: 22372.331298
# Log likelihood: 22362.483728
# Log likelihood: 22376.238120
# Log likelihood: 22361.822794
# Log likelihood: 22375.145537
# Log likelihood: 22369.213377
# Log likelihood: 22366.581645
# Log likelihood: 22377.885520
# Log likelihood: 22363.733204
# Log likelihood: 22363.313735
# Log likelihood: 22369.700039
# Log likelihood: 22361.530728
# Log likelihood: 22389.234035
# Log likelihood: 22360.304768
# Log likelihood: 22361.458194
# Log likelihood: 22361.445370
# Log likelihood: 22364.703038
# Log likelihood: 22359.858888
# Log likelihood: 22363.590992
# Log likelihood: 22359.544211
# Log likelihood: 22361.498295
# Log likelihood: 22364.413211
# Log likelihood: 22359.136055
# Log likelihood: 22361.167609
# Log likelihood: 22364.212696
# Log likelihood: 22359.212139
# Log likelihood: 22362.865991
# Log likelihood: 22359.232815
# Log likelihood: 22360.441514
# Log likelihood: 22359.067698
# Log likelihood: 22363.342538
# Log likelihood: 22358.830687
# Log likelihood: 22359.743215
# Log likelihood: 22358.935601
# Log likelihood: 22359.615735
# Log likelihood: 22358.884476
# Log likelihood: 22359.040409
# Log likelihood: 22358.634460
# Log likelihood: 22359.320022
# Log likelihood: 22359.642549
# Log likelihood: 22358.662599
# Log likelihood: 22358.892168
# Log likelihood: 22359.456681
# Log likelihood: 22358.637787
# Log likelihood: 22358.895556
# Log likelihood: 22358.629929
# Log likelihood: 22358.924543
# Log likelihood: 22358.621708
# Log likelihood: 22358.993145
# Log likelihood: 22358.613426
# Log likelihood: 22358.762684
# Log likelihood: 22358.579540
# Log likelihood: 22358.537816
# Log likelihood: 22358.720336
# Log likelihood: 22358.794768
# Log likelihood: 22358.529628
# Log likelihood: 22359.002262
# Log likelihood: 22358.512994
# Log likelihood: 22358.576284
# Log likelihood: 22358.541403
# Log likelihood: 22358.387066
# Log likelihood: 22358.312070
# Log likelihood: 22358.473199
# Log likelihood: 22358.468197
# Log likelihood: 22358.607392
# Log likelihood: 22358.447661
# Log likelihood: 22358.470468
# Log likelihood: 22358.375518
# Log likelihood: 22358.310952
# Log likelihood: 22358.307039
# Log likelihood: 22358.458446
# Log likelihood: 22358.253361
# Log likelihood: 22358.225236
# Log likelihood: 22358.159052
# Log likelihood: 22358.095428
# Log likelihood: 22358.311728
# Log likelihood: 22358.006671
# Log likelihood: 22357.901784
# Log likelihood: 22358.033156
# Log likelihood: 22357.985405
# Log likelihood: 22357.859364
# Log likelihood: 22357.886275
# Log likelihood: 22357.579291
# Log likelihood: 22357.296628
# Log likelihood: 22357.520876
# Log likelihood: 22357.834734
# Log likelihood: 22357.393489
# Log likelihood: 22357.285900
# Log likelihood: 22357.246413
# Log likelihood: 22356.832959
# Log likelihood: 22356.303697
# Log likelihood: 22356.670721
# Log likelihood: 22356.695467
# Log likelihood: 22356.500903
# Log likelihood: 22356.063868
# Log likelihood: 22355.682180
# Log likelihood: 22355.910081
# Log likelihood: 22355.163922
# Log likelihood: 22354.432696
# Log likelihood: 22355.183001
# Log likelihood: 22354.468696
# Log likelihood: 22353.862554
# Log likelihood: 22352.814773
# Log likelihood: 22353.843110
# Log likelihood: 22353.464374
# Log likelihood: 22352.184788
# Log likelihood: 22350.953202
# Log likelihood: 22351.799781
# Log likelihood: 22352.349320
# Log likelihood: 22350.440711
# Log likelihood: 22349.210760
# Log likelihood: 22350.668675
# Log likelihood: 22349.103805
# Log likelihood: 22348.200111
# Log likelihood: 22349.482089
# Log likelihood: 22346.472919
# Log likelihood: 22343.665819
# Log likelihood: 22347.068266
# Log likelihood: 22347.432033
# Log likelihood: 22345.475172
# Log likelihood: 22343.154290
# Log likelihood: 22340.562926
# Log likelihood: 22344.029825
# Log likelihood: 22341.183805
# Log likelihood: 22339.892113
# Log likelihood: 22338.244696
# Log likelihood: 22336.950993
# Log likelihood: 22334.479455
# Log likelihood: 22333.760332
# Log likelihood: 22329.826892
# Log likelihood: 22333.023356
# Log likelihood: 22330.360735
# Log likelihood: 22333.181213
# Log likelihood: 22327.178634
# Log likelihood: 22326.564261
# Log likelihood: 22324.143613
# Log likelihood: 22323.833384
# Log likelihood: 22324.993789
# Log likelihood: 22316.737264
# Log likelihood: 22309.434858
# Log likelihood: 22321.937633
# Log likelihood: 22316.626305
# Log likelihood: 22329.369717
# Log likelihood: 22321.162426
# Log likelihood: 22309.970176
# Log likelihood: 22314.715322
# Log likelihood: 22307.257377
# Log likelihood: 22304.987616
# Log likelihood: 22298.403525
# Log likelihood: 22288.410088
# Log likelihood: 22288.836185
# Log likelihood: 22287.293537
# Log likelihood: 22281.181475
# Log likelihood: 22279.712099
# Log likelihood: 22274.538800
# Log likelihood: 22268.511203
# Log likelihood: 22262.045698
# Log likelihood: 22245.936624
# Log likelihood: 22222.511128
# Log likelihood: 22230.745948
# Log likelihood: 22226.560597
# Log likelihood: 22251.468410
# Log likelihood: 22223.102660
# Log likelihood: 22206.980775
# Log likelihood: 22230.536354
# Log likelihood: 22169.770055
# Log likelihood: 22125.967605
# Log likelihood: 22168.895197
# Log likelihood: 22175.350891
# Log likelihood: 22137.566457
# Log likelihood: 22143.842931
# Log likelihood: 22105.261702
# Log likelihood: 22112.791420
# Log likelihood: 22086.303818
# Log likelihood: 22062.585066
# Log likelihood: 22052.003563
# Log likelihood: 22011.625089
# Log likelihood: 22021.331356
# Log likelihood: 21995.745306
# Log likelihood: 21953.520269
# Log likelihood: 21905.682077
# Log likelihood: 21792.094653
# Log likelihood: 21838.495583
# Log likelihood: 21819.374678
# Log likelihood: 21720.730714
# Log likelihood: 21594.778274
# Log likelihood: 21659.303796
# Log likelihood: 21540.104497
# Log likelihood: 21383.180774
# Log likelihood: 21451.321385
# Log likelihood: 21320.050563
# Log likelihood: 21156.254512
# Log likelihood: 21300.109154
# Log likelihood: 21056.760294
# Log likelihood: 22062.451388
# Log likelihood: 21223.097461
# Log likelihood: 20990.269389
# Log likelihood: 21836.262416
# Log likelihood: 21362.474379
# Log likelihood: 22167.160090
# Log likelihood: 21137.756558
# Log likelihood: 21414.758016
# Log likelihood: 21087.770966
# Log likelihood: 20833.779923
# Log likelihood: 20732.784476
# Log likelihood: 20959.976574
# Log likelihood: 20778.815467
# Log likelihood: 21413.741002
# Log likelihood: 20962.019843
# Log likelihood: 20865.596087
# Log likelihood: 20722.409649
# Log likelihood: 20709.547877
# Log likelihood: 20736.326827
# Log likelihood: 20678.728187
# Log likelihood: 20726.248537
# Log likelihood: 20687.705950
# Log likelihood: 20557.766898
# Log likelihood: 20540.996707
# Log likelihood: 20640.572247
# Log likelihood: 20852.826253
# Log likelihood: 20637.670427
# Log likelihood: 20790.268755
# Log likelihood: 20619.018403
# Log likelihood: 20517.404070
# Log likelihood: 20510.007734
# Log likelihood: 20476.506886
# Log likelihood: 20457.437911
# Log likelihood: 20424.468424
# Log likelihood: 20427.311813
# Log likelihood: 20498.960145
# Log likelihood: 20410.608457
# Log likelihood: 20649.022418
# Log likelihood: 20343.353105
# Log likelihood: 20374.928881
# Log likelihood: 20306.870077
# Log likelihood: 20410.509383
# Log likelihood: 20392.776480
# Log likelihood: 20304.601612
# Log likelihood: 20368.104892
# Log likelihood: 20479.133764
# Log likelihood: 20354.536627
# Log likelihood: 20273.812246
# Log likelihood: 20351.055062
# Log likelihood: 20341.739384
# Log likelihood: 20275.238225
# Log likelihood: 20228.815028
# Log likelihood: 20257.972460
# Log likelihood: 20276.743512
# Log likelihood: 20407.836725
# Log likelihood: 20271.357344
# Log likelihood: 20284.486115
# Log likelihood: 20274.937197
# Log likelihood: 20352.652598
# Log likelihood: 20245.390882
# Log likelihood: 20278.566329
# Log likelihood: 20246.013727
# Log likelihood: 20328.410882
# Log likelihood: 20240.296909
# Log likelihood: 20290.159878
# Log likelihood: 20243.084896
# Log likelihood: 20235.823987
# Log likelihood: 20233.028992
# Log likelihood: 20234.011876
# Log likelihood: 20236.869676
# Log likelihood: 20264.695153
# Log likelihood: 20225.472987
# Log likelihood: 20220.490423
# Log likelihood: 20236.444753
# Log likelihood: 20233.493360
# Log likelihood: 20266.736516
# Log likelihood: 20222.203952
# Log likelihood: 20220.411947
# Log likelihood: 20238.416095
# Log likelihood: 20242.348091
# Log likelihood: 20221.811856
# Log likelihood: 20221.409044
# Log likelihood: 20228.470104
# Log likelihood: 20219.886249
# Log likelihood: 20216.531000
# Log likelihood: 20226.090274
# Log likelihood: 20216.786294
# Log likelihood: 20210.995467
# Log likelihood: 20213.836950
# Log likelihood: 20228.792650
# Log likelihood: 20214.390915
# Log likelihood: 20229.094507
# Log likelihood: 20214.057770
# Log likelihood: 20215.507345
# Log likelihood: 20214.707208
# Log likelihood: 20212.033450
# Log likelihood: 20212.569465
# Log likelihood: 20212.426898
# Log likelihood: 20215.120141
# Log likelihood: 20211.248310
# Log likelihood: 20213.675640
# Log likelihood: 20208.109855
# Log likelihood: 20209.966203
# Log likelihood: 20212.425005
# Log likelihood: 20208.301851
# Log likelihood: 20212.537520
# Log likelihood: 20209.273068
# Log likelihood: 20209.969552
# Log likelihood: 20217.084227
# Log likelihood: 20208.609857
# Log likelihood: 20206.041192
# Log likelihood: 20206.402040
# Log likelihood: 20206.469502
# Log likelihood: 20209.124681
# Log likelihood: 20205.917366
# Log likelihood: 20208.034803
# Log likelihood: 20208.769725
# Log likelihood: 20206.658164
# Log likelihood: 20203.925416
# Log likelihood: 20203.512570
# Log likelihood: 20205.048887
# Log likelihood: 20204.589279
# Log likelihood: 20202.358170
# Log likelihood: 20202.570028
# Log likelihood: 20203.785024
# Log likelihood: 20202.741217
# Log likelihood: 20203.724014
# Log likelihood: 20204.127277
# Log likelihood: 20207.126940
# Log likelihood: 20202.543728
# Log likelihood: 20205.188682
# Log likelihood: 20202.546708
# Log likelihood: 20202.149567
# Log likelihood: 20204.204537
# Log likelihood: 20205.385989
# Log likelihood: 20202.181125
# Log likelihood: 20202.395141
# Log likelihood: 20202.602279
# Log likelihood: 20201.949449
# Log likelihood: 20202.583211
# Log likelihood: 20201.941890
# Log likelihood: 20201.742554
# Log likelihood: 20202.789635
# Log likelihood: 20203.736573
# Log likelihood: 20201.710622
# Log likelihood: 20201.723406
# Log likelihood: 20202.109403
# Log likelihood: 20202.028624
# Log likelihood: 20202.376970
# Log likelihood: 20201.654613
# Log likelihood: 20202.063253
# Log likelihood: 20201.651632
# Log likelihood: 20201.935234
# Log likelihood: 20202.059974
# Log likelihood: 20201.617896
# Log likelihood: 20201.800329
# Log likelihood: 20201.565008
# Log likelihood: 20202.168075
# Log likelihood: 20201.525130
# Log likelihood: 20202.298280
# Log likelihood: 20201.518099
# Log likelihood: 20201.597826
# Log likelihood: 20201.751957
# Log likelihood: 20201.539296
# Log likelihood: 20201.564673
# Log likelihood: 20201.460490
# Log likelihood: 20201.533586
# Log likelihood: 20201.670311
# Log likelihood: 20201.500961
# Log likelihood: 20201.619857
# Log likelihood: 20201.495096
# Log likelihood: 20201.495071
# Log likelihood: 20201.517720
# Log likelihood: 20201.501372
# Log likelihood: 20201.505706
# Log likelihood: 20201.544861
# Log likelihood: 20201.472175
# Log likelihood: 20201.512638
# Log likelihood: 20201.470950
# Log likelihood: 20201.519455
# Log likelihood: 20201.468836
# Log likelihood: 20201.430118
# Log likelihood: 20201.425840
# Log likelihood: 20201.456386
# Log likelihood: 20201.503620
# Log likelihood: 20201.452602
# Log likelihood: 20201.426404
# Log likelihood: 20201.450551
# Log likelihood: 20201.432556
# Log likelihood: 20201.471174
# Log likelihood: 20201.432445
# Log likelihood: 20201.449247
# Log likelihood: 20201.477553
# Log likelihood: 20201.428640
# Log likelihood: 20201.424198
# Log likelihood: 20201.457431
# Log likelihood: 20201.438121
# Log likelihood: 20201.422378
# Log likelihood: 20201.460849
# Log likelihood: 20201.419752
# Log likelihood: 20201.425612
# Log likelihood: 20201.414650
# Log likelihood: 20201.420737
# Log likelihood: 20201.411603
# Log likelihood: 20201.415477
# Log likelihood: 20201.416175
# Log likelihood: 20201.428967
# Log likelihood: 20201.415637
# Log likelihood: 20201.423217
# Log likelihood: 20201.415037
# Log likelihood: 20201.416354
# Log likelihood: 20201.414729
# Log likelihood: 20201.417839
# Log likelihood: 20201.412084
# Log likelihood: 20201.422279
# Log likelihood: 20201.411647
# Log likelihood: 20201.411666
# Log likelihood: 20201.419633
# Log likelihood: 20201.411124
# Log likelihood: 20201.419234
# Log likelihood: 20201.411122
# Log likelihood: 20201.407887
# Log likelihood: 20201.408225
# Log likelihood: 20201.409323
# Log likelihood: 20201.410889
# Log likelihood: 20201.408608
# Log likelihood: 20201.409385
# Log likelihood: 20201.407339
# Log likelihood: 20201.409125
# Log likelihood: 20201.409087
# Log likelihood: 20201.408502
# Log likelihood: 20201.412035
# Log likelihood: 20201.407463
# Log likelihood: 20201.405158
# Log likelihood: 20201.404168
# Log likelihood: 20201.408737
# Log likelihood: 20201.406809
# Log likelihood: 20201.408726
# Log likelihood: 20201.406781
# Log likelihood: 20201.408681
# Log likelihood: 20201.406718
# Log likelihood: 20201.404368
# Log likelihood: 20201.405709
# Log likelihood: 20201.405913
# Log likelihood: 20201.403994
# Log likelihood: 20201.403837
# Log likelihood: 20201.402880
# Log likelihood: 20201.402378
# Log likelihood: 20201.402184
# Log likelihood: 20201.402825
# Log likelihood: 20201.402564
# Log likelihood: 20201.399522
# Log likelihood: 20201.397520
# Log likelihood: 20201.403061
# Log likelihood: 20201.399459
# Log likelihood: 20201.400132
# Log likelihood: 20201.399027
# Log likelihood: 20201.397112
# Log likelihood: 20201.396849
# Log likelihood: 20201.394239
# Log likelihood: 20201.391908
# Log likelihood: 20201.391766
# Log likelihood: 20201.389952
# Log likelihood: 20201.390683
# Log likelihood: 20201.386549
# Log likelihood: 20201.382645
# Log likelihood: 20201.388234
# Log likelihood: 20201.380013
# Log likelihood: 20201.374852
# Log likelihood: 20201.379928
# Log likelihood: 20201.378322
# Log likelihood: 20201.377548
# Log likelihood: 20201.370859
# Log likelihood: 20201.370026
# Log likelihood: 20201.359907
# Log likelihood: 20201.349024
# Log likelihood: 20201.368792
# Log likelihood: 20201.364276
# Log likelihood: 20201.355841
# Log likelihood: 20201.347956
# Log likelihood: 20201.343241
# Log likelihood: 20201.358612
# Log likelihood: 20201.339364
# Log likelihood: 20201.335558
# Log likelihood: 20201.331134
# Log likelihood: 20201.330235
# Log likelihood: 20201.315994
# Log likelihood: 20201.305585
# Log likelihood: 20201.299875
# Log likelihood: 20201.284043
# Log likelihood: 20201.277286
# Log likelihood: 20201.254804
# Log likelihood: 20201.290340
# Log likelihood: 20201.265577
# Log likelihood: 20201.273636
# Log likelihood: 20201.198381
# Log likelihood: 20201.137927
# Log likelihood: 20201.209088
# Log likelihood: 20201.191177
# Log likelihood: 20201.232483
# Log likelihood: 20201.163838
# Log likelihood: 20201.104592
# Log likelihood: 20201.035935
# Log likelihood: 20201.069381
# Log likelihood: 20201.099702
# Log likelihood: 20201.010296
# Log likelihood: 20200.944067
# Log likelihood: 20200.927971
# Log likelihood: 20200.818604
# Log likelihood: 20200.841016
# Log likelihood: 20200.792096
# Log likelihood: 20200.682818
# Log likelihood: 20200.735063
# Log likelihood: 20200.558621
# Log likelihood: 20200.322709
# Log likelihood: 20200.418154
# Log likelihood: 20200.318992
# Log likelihood: 20200.096326
# Log likelihood: 20200.161318
# Log likelihood: 20200.042193
# Log likelihood: 20199.864377
# Log likelihood: 20199.758474
# Log likelihood: 20199.458197
# Log likelihood: 20199.238944
# Log likelihood: 20198.560043
# Log likelihood: 20199.024376
# Log likelihood: 20198.951914
# Log likelihood: 20198.533189
# Log likelihood: 20198.082021
# Log likelihood: 20198.338726
# Log likelihood: 20197.445951
# Log likelihood: 20196.467670
# Log likelihood: 20197.005880
# Log likelihood: 20196.815860
# Log likelihood: 20196.020915
# Log likelihood: 20194.929799
# Log likelihood: 20196.844978
# Log likelihood: 20194.803538
# Log likelihood: 20193.400179
# Log likelihood: 20193.631747
# Log likelihood: 20194.252218
# Log likelihood: 20193.126901
# Log likelihood: 20192.243601
# Log likelihood: 20190.937936
# Log likelihood: 20188.446348
# Log likelihood: 20189.093852
# Log likelihood: 20189.046507
# Log likelihood: 20187.500614
# Log likelihood: 20185.188523
# Log likelihood: 20184.990609
# Log likelihood: 20181.712763
# Log likelihood: 20181.794988
# Log likelihood: 20180.578247
# Log likelihood: 20178.267870
# Log likelihood: 20179.553297
# Log likelihood: 20174.429193
# Log likelihood: 20168.545324
# Log likelihood: 20171.157173
# Log likelihood: 20169.734233
# Log likelihood: 20168.547081
# Log likelihood: 20164.393372
# Log likelihood: 20160.613476
# Log likelihood: 20158.551539
# Log likelihood: 20152.441478
# Log likelihood: 20157.693667
# Log likelihood: 20155.471428
# Log likelihood: 20149.995194
# Log likelihood: 20145.321749
# Log likelihood: 20143.683973
# Log likelihood: 20138.463636
# Log likelihood: 20156.222095
# Log likelihood: 20139.890435
# Log likelihood: 20149.378210
# Log likelihood: 20141.118658
# Log likelihood: 20133.242183
# Log likelihood: 20132.459533
# Log likelihood: 20136.272752
# Log likelihood: 20135.192310
# Log likelihood: 20125.326080
# Log likelihood: 20124.006218
# Log likelihood: 20155.512386
# Log likelihood: 20130.958245
# Log likelihood: 20120.628203
# Log likelihood: 20115.934888
# Log likelihood: 20120.821780
# Log likelihood: 20112.768925
# Log likelihood: 20109.067827
# Log likelihood: 20116.864488
# Log likelihood: 20105.986237
# Log likelihood: 20106.960676
# Log likelihood: 20124.910310
# Log likelihood: 20114.628233
# Log likelihood: 20101.800531
# Log likelihood: 20098.876584
# Log likelihood: 20097.363980
# Log likelihood: 20096.467316
# Log likelihood: 20111.290135
# Log likelihood: 20105.361837
# Log likelihood: 20115.844545
# Log likelihood: 20103.622736
# Log likelihood: 20098.302232
# Log likelihood: 20096.769438
# Log likelihood: 20096.854560
# Log likelihood: 20103.964362
# Log likelihood: 20096.942844
# Log likelihood: 20090.499691
# Log likelihood: 20093.234330
# Log likelihood: 20102.068742
# Log likelihood: 20094.067521
# Log likelihood: 20099.124392
# Log likelihood: 20094.093180
# Log likelihood: 20095.930845
# Log likelihood: 20092.417018
# Log likelihood: 20090.712052
# Log likelihood: 20090.804997
# Log likelihood: 20096.211477
# Log likelihood: 20091.790542
# Log likelihood: 20088.552918
# Log likelihood: 20089.783438
# Log likelihood: 20088.136798
# Log likelihood: 20090.971218
# Log likelihood: 20093.203148
# Log likelihood: 20089.514967
# Log likelihood: 20085.760102
# Log likelihood: 20084.221001
# Log likelihood: 20089.932912
# Log likelihood: 20087.543051
# Log likelihood: 20084.774993
# Log likelihood: 20087.026667
# Log likelihood: 20083.896003
# Log likelihood: 20085.381461
# Log likelihood: 20083.455006
# Log likelihood: 20085.539836
# Log likelihood: 20082.387512
# Log likelihood: 20084.239123
# Log likelihood: 20081.778649
# Log likelihood: 20084.574772
# Log likelihood: 20081.543203
# Log likelihood: 20085.718866
# Log likelihood: 20085.764281
# Log likelihood: 20082.326933
# Log likelihood: 20079.392856
# Log likelihood: 20078.439460
# Log likelihood: 20080.255550
# Log likelihood: 20078.508905
# Log likelihood: 20082.841948
# Log likelihood: 20080.088881
# Log likelihood: 20077.489452
# Log likelihood: 20077.855697
# Log likelihood: 20077.841100
# Log likelihood: 20074.575100
# Log likelihood: 20072.400985
# Log likelihood: 20075.454596
# Log likelihood: 20072.618420
# Log likelihood: 20075.331945
# Log likelihood: 20071.567595
# Log likelihood: 20071.419048
# Log likelihood: 20070.507499
# Log likelihood: 20071.811721
# Log likelihood: 20067.168148
# Log likelihood: 20065.176746
# Log likelihood: 20065.691951
# Log likelihood: 20066.035524
# Log likelihood: 20069.150712
# Log likelihood: 20063.840788
# Log likelihood: 20066.198879
# Log likelihood: 20062.640800
# Log likelihood: 20064.793944
# Log likelihood: 20058.002609
# Log likelihood: 20054.777677
# Log likelihood: 20057.060213
# Log likelihood: 20063.302621
# Log likelihood: 20059.765718
# Log likelihood: 20056.287151
# Log likelihood: 20057.428511
# Log likelihood: 20052.796680
# Log likelihood: 20054.974326
# Log likelihood: 20049.803479
# Log likelihood: 20050.268799
# Log likelihood: 20048.832388
# Log likelihood: 20049.908905
# Log likelihood: 20057.744272
# Log likelihood: 20052.958255
# Log likelihood: 20057.212290
# Log likelihood: 20052.723073
# Log likelihood: 20047.245383
# Log likelihood: 20046.005516
# Log likelihood: 20045.106653
# Log likelihood: 20043.878820
# Log likelihood: 20042.482862
# Log likelihood: 20040.422685
# Log likelihood: 20043.236752
# Log likelihood: 20034.179433
# Log likelihood: 20027.691228
# Log likelihood: 20038.906634
# Log likelihood: 20042.120929
# Log likelihood: 20033.361438
# Log likelihood: 20031.233705
# Log likelihood: 20031.350927
# Log likelihood: 20030.629439
# Log likelihood: 20027.849084
# Log likelihood: 20021.603309
# Log likelihood: 20022.797188
# Log likelihood: 20021.194685
# Log likelihood: 20022.234597
# Log likelihood: 20025.053033
# Log likelihood: 20017.151639
# Log likelihood: 20015.915339
# Log likelihood: 20022.832969
# Log likelihood: 20021.702495
# Log likelihood: 20014.790007
# Log likelihood: 20021.138378
# Log likelihood: 20014.013165
# Log likelihood: 20021.310940
# Log likelihood: 20022.764252
# Log likelihood: 20016.612773
# Log likelihood: 20019.093851
# Log likelihood: 20012.974559
# Log likelihood: 20020.120935
# Log likelihood: 20016.716903
# Log likelihood: 20024.837970
# Log likelihood: 20013.481571
# Log likelihood: 20019.839511
# Log likelihood: 20013.172832
# Log likelihood: 20013.298198
# Log likelihood: 20017.187146
# Log likelihood: 20012.889028
# Log likelihood: 20013.172184
# Log likelihood: 20012.977798
# Log likelihood: 20015.179120
# Log likelihood: 20011.894970
# Log likelihood: 20015.592740
# Log likelihood: 20011.825442
# Log likelihood: 20012.074523
# Log likelihood: 20015.537874
# Log likelihood: 20011.719736
# Log likelihood: 20012.771442
# Log likelihood: 20013.840699
# Log likelihood: 20011.786847
# Log likelihood: 20012.822189
# Log likelihood: 20011.812436
# Log likelihood: 20012.327049
# Log likelihood: 20011.594149
# Log likelihood: 20012.453984
# Log likelihood: 20011.551810
# Log likelihood: 20012.169399
# Log likelihood: 20011.513596
# Log likelihood: 20012.607874
# Log likelihood: 20011.459223
# Log likelihood: 20011.843731
# Log likelihood: 20011.528155
# Log likelihood: 20011.592787
# Log likelihood: 20011.719821
# Log likelihood: 20011.484262
# Log likelihood: 20011.823322
# Log likelihood: 20011.431584
# Log likelihood: 20011.741327
# Log likelihood: 20011.441478
# Log likelihood: 20011.680340
# Log likelihood: 20011.434902
# Log likelihood: 20011.433299
# Log likelihood: 20011.494150
# Log likelihood: 20011.418437
# Log likelihood: 20011.434097
# Log likelihood: 20011.420096
# Log likelihood: 20011.472609
# Log likelihood: 20011.394508
# Log likelihood: 20011.459709
# Log likelihood: 20011.393492
# Log likelihood: 20011.475639
# Log likelihood: 20011.391834
# Log likelihood: 20011.543321
# Log likelihood: 20011.386658
# Log likelihood: 20011.385392
# Log likelihood: 20011.440516
# Log likelihood: 20011.449303
# Log likelihood: 20011.386715
# Log likelihood: 20011.396411
# Log likelihood: 20011.379468
# Log likelihood: 20011.375877
# Log likelihood: 20011.396045
# Log likelihood: 20011.381700
# Log likelihood: 20011.378370
# Log likelihood: 20011.392072
# Log likelihood: 20011.373967
# Log likelihood: 20011.377511
# Log likelihood: 20011.392157
# Log likelihood: 20011.372495
# Log likelihood: 20011.396952
# Log likelihood: 20011.370902
# Log likelihood: 20011.372734
# Log likelihood: 20011.375264
# Log likelihood: 20011.381446
# Log likelihood: 20011.369929
# Log likelihood: 20011.386004
# Log likelihood: 20011.369025
# Log likelihood: 20011.379405
# Log likelihood: 20011.369480
# Log likelihood: 20011.369099
# Log likelihood: 20011.377432
# Log likelihood: 20011.368330
# Log likelihood: 20011.369570
# Log likelihood: 20011.370890
# Log likelihood: 20011.367980
# Log likelihood: 20011.368892
# Log likelihood: 20011.369381
# Log likelihood: 20011.368348
# Log likelihood: 20011.368391
# Log likelihood: 20011.371233
# Log likelihood: 20011.366983
# Log likelihood: 20011.371972
# Log likelihood: 20011.366916
# Log likelihood: 20011.369584
# Log likelihood: 20011.367099
# Log likelihood: 20011.369761
# Log likelihood: 20011.366918
# Log likelihood: 20011.369122
# Log likelihood: 20011.366964
# Log likelihood: 20011.368413
# Log likelihood: 20011.367009
# Log likelihood: 20011.368041
# Log likelihood: 20011.366910
# Log likelihood: 20011.367071
# Log likelihood: 20011.366682
# Log likelihood: 20011.366655
# Log likelihood: 20011.367396
# Log likelihood: 20011.367330
# Log likelihood: 20011.366592
# Log likelihood: 20011.367364
# Log likelihood: 20011.366585
# Log likelihood: 20011.366708
# Log likelihood: 20011.367656
# Log likelihood: 20011.366528
# Log likelihood: 20011.366437
# Log likelihood: 20011.366837
# Log likelihood: 20011.366867
# Log likelihood: 20011.366484
# Log likelihood: 20011.366569
# Log likelihood: 20011.366704
# Log likelihood: 20011.366468
# Log likelihood: 20011.366454
# Log likelihood: 20011.366529
# Log likelihood: 20011.366470
# Log likelihood: 20011.366653
# Log likelihood: 20011.366399
# Log likelihood: 20011.366386
# Log likelihood: 20011.366605
# Log likelihood: 20011.366460
# Log likelihood: 20011.366700
# Log likelihood: 20011.366359
# Log likelihood: 20011.366446
# Log likelihood: 20011.366442
# Log likelihood: 20011.366498
# Log likelihood: 20011.366369
# Log likelihood: 20011.366461
# Log likelihood: 20011.366370
# Log likelihood: 20011.366429
# Log likelihood: 20011.366453
# Log likelihood: 20011.366365
# Log likelihood: 20011.366438
# Log likelihood: 20011.366363
# Log likelihood: 20011.366440
# Log likelihood: 20011.366353
# Log likelihood: 20011.366444
# Log likelihood: 20011.366349
# Log likelihood: 20011.366371
# Log likelihood: 20011.366350
# Log likelihood: 20011.366349
# Log likelihood: 20011.366347
# Log likelihood: 20011.366387
# Log likelihood: 20011.366360
# Log likelihood: 20011.366343
# Log likelihood: 20011.366361
# Log likelihood: 20011.366343
# Log likelihood: 20011.366353
# Log likelihood: 20011.366341
# Log likelihood: 20011.366340
# Log likelihood: 20011.366361
# Log likelihood: 20011.366372
# Log likelihood: 20011.366337
# Log likelihood: 20011.366363
# Log likelihood: 20011.366338
# Log likelihood: 20011.366353
# Log likelihood: 20011.366338
# Log likelihood: 20011.366338
# Log likelihood: 20011.366339
# Log likelihood: 20011.366339
# Log likelihood: 20011.366342
# Log likelihood: 20011.366336
# Log likelihood: 20011.366342
# Log likelihood: 20011.366336
# Log likelihood: 20011.366339
# Log likelihood: 20011.366336
# Log likelihood: 20011.366337
# Log likelihood: 20011.366348
# Log likelihood: 20011.366335
# Log likelihood: 20011.366335
# Log likelihood: 20011.366339
# Log likelihood: 20011.366335
# Log likelihood: 20011.366337
# Log likelihood: 20011.366335
# Log likelihood: 20011.366333
# Log likelihood: 20011.366334
# Log likelihood: 20011.366335
# Log likelihood: 20011.366335
# Log likelihood: 20011.366336
# Log likelihood: 20011.366334
# Log likelihood: 20011.366334
# Log likelihood: 20011.366334
# Log likelihood: 20011.366334
# Log likelihood: 20011.366333
# Log likelihood: 20011.366334
# Estimated mean vector: [-0.1026  0.0118]
# Estimated shape matrix: [[ 0.6449 -0.2471]
#  [-0.2471  0.1994]]
# Estimated degrees of freedom:   3.91
# Optimization terminated successfully.
#
# Actual mean vector: [-0.105  0.015]
# Actual shape matrix: [[ 0.65 -0.25]
#  [-0.25  0.2 ]]
# Actual degrees of freedom:   4.00
